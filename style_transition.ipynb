# %%
import os, shutil
from IPython.display import display
from PIL import Image

# %%
os.chdir('../data/style_transfer')
print(os.getcwd())
# Out:
# /home/ubuntu/data/style_transfer

# %%
from keras.preprocessing.image import load_img, img_to_array

os.listdir()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# ['style_transfer_result_p2_at_iteration_7.png',
#  'xl_earring.jpg',
#  'style_transfer_result_p2_at_iteration_39.png',
#  'style_transfer_result_p2_at_iteration_20.png',
#  'style_transfer_result_p2_at_iteration_32.png',
#  'style_transfer_result_p2_at_iteration_33.png',
#  'style_transfer_result_at_iteration_7.png',
#  'style_transfer_result_p2_at_iteration_49.png',
#  'style_transfer_result_at_iteration_2.png',
#  'style_transfer_result_at_iteration_33.png',
#  'style_transfer_result_p2_at_iteration_12.png',
#  'style_transfer_result_p2_at_iteration_2.png',
#  'style_transfer_result_at_iteration_35.png',
#  'style_transfer_result_p2_at_iteration_16.png',
#  'style_transfer_result_p2_at_iteration_1.png',
#  'style_transfer_result_at_iteration_32.png',
#  'style_transfer_result_at_iteration_37.png',
#  'style_transfer_result_at_iteration_36.png',
#  'style_transfer_result_at_iteration_8.png',
#  'style_transfer_result_p2_at_iteration_13.png',
#  'style_transfer_result_p2_at_iteration_14.png',
#  'style_transfer_result_at_iteration_13.png',
#  'transition.jpg',
#  'style_transfer_result_p2_at_iteration_48.png',
#  'style_transfer_result_p2_at_iteration_4.png',
#  'style_transfer_result_at_iteration_9.png',
#  'style_transfer_result_at_iteration_3.png',
#  'style_transfer_result_p2_at_iteration_21.png',
#  'style_transfer_result_at_iteration_48.png',
#  'style_transfer_result_p2_at_iteration_37.png',
#  'style_transfer_result_p2_at_iteration_44.png',
#  'style_transfer_result_at_iteration_19.png',
#  'style_transfer_result_at_iteration_5.png',
#  'style_transfer_result_at_iteration_30.png',
#  'style_transfer_result_at_iteration_43.png',
#  'style_transfer_result_at_iteration_4.png',
#  'style_transfer_result_p2_at_iteration_38.png',
#  'style_transfer_result_p2_at_iteration_29.png',
#  'style_transfer_result_p2_at_iteration_43.png',
#  'style_transfer_result_at_iteration_23.png',
#  'style_transfer_result_p2_at_iteration_17.png',
#  'style_transfer_result_at_iteration_15.png',
#  'style_transfer_result_at_iteration_42.png',
#  'style_transfer_result_at_iteration_1.png',
#  'style_transfer_result_at_iteration_27.png',
#  'style_transfer_result_at_iteration_12.png',
#  'style_transfer_result_p2_at_iteration_11.png',
#  'style_transfer_result_p2_at_iteration_19.png',
#  'style_transfer_result_at_iteration_40.png',
#  'renaissance.jpg',
#  'style_transfer_result_p2_at_iteration_28.png',
#  'style_transfer_result_p2_at_iteration_23.png',
#  'style_transfer_result_p2_at_iteration_25.png',
#  'style_transfer_result_p2_at_iteration_45.png',
#  'style_transfer_result_p2_at_iteration_42.png',
#  'composition-II-in-red-blue-and-yellow.jpg',
#  'style_transfer_result_at_iteration_46.png',
#  'style_transfer_result_at_iteration_49.png',
#  'romanticism.jpg',
#  'style_transfer_result_at_iteration_38.png',
#  'style_transfer_result_p2_at_iteration_10.png',
#  'style_transfer_result_at_iteration_20.png',
#  'style_transfer_result_p2_at_iteration_40.png',
#  'style_transfer_result_at_iteration_22.png',
#  'style_transfer_result_p2_at_iteration_36.png',
#  'style_transfer_result_p2_at_iteration_9.png',
#  'style_transfer_result_at_iteration_41.png',
#  'style_transfer_result_p2_at_iteration_6.png',
#  'style_transfer_result_at_iteration_28.png',
#  'style_transfer_result_p2_at_iteration_18.png',
#  'style_transfer_result_at_iteration_34.png',
#  'style_transfer_result_p2_at_iteration_5.png',
#  'style_transfer_result_at_iteration_11.png',
#  'style_transfer_result_at_iteration_26.png',
#  'Sunday.jpg',
#  'style_transfer_result_p2_at_iteration_24.png',
#  'style_transfer_result_p2_at_iteration_0.png',
#  'style_transfer_result_at_iteration_16.png',
#  'style_transfer_result_at_iteration_24.png',
#  'style_transfer_result_at_iteration_0.png',
#  'style_transfer_result_at_iteration_29.png',
#  'style_transfer_result_at_iteration_44.png',
#  'style_transfer_result_at_iteration_31.png',
#  'style_transfer_result_p2_at_iteration_41.png',
#  'style_transfer_result_at_iteration_45.png',
#  'style_transfer_result_p2_at_iteration_27.png',
#  'Picasso.jpg',
#  'style_transfer_result_at_iteration_18.png',
#  'style_transfer_result_at_iteration_17.png',
#  'mario03.png',
#  'style_transfer_result_at_iteration_10.png',
#  'style_transfer_result_p2_at_iteration_26.png',
#  'style_transfer_result_p2_at_iteration_46.png',
#  'style_transfer_result_at_iteration_21.png',
#  'style_transfer_result_p2_at_iteration_15.png',
#  'style_transfer_result_p2_at_iteration_35.png',
#  'style_transfer_result_at_iteration_39.png',
#  'style_transfer_result_p2_at_iteration_34.png',
#  'style_transfer_result_at_iteration_14.png',
#  'style_transfer_result_p2_at_iteration_31.png',
#  'style_transfer_result_p2_at_iteration_3.png',
#  'style_transfer_result_p2_at_iteration_47.png',
#  'style_transfer_result_at_iteration_25.png',
#  'style_transfer_result_p2_at_iteration_30.png',
#  'style_transfer_result_at_iteration_6.png',
#  'style_transfer_result_p2_at_iteration_22.png',
#  'style_transfer_result_p2_at_iteration_8.png',
#  'style_transfer_result_at_iteration_47.png']

# %%
# This is the path to the image you want to transform.
target_image_path = 'xl_earring.jpg'
# This is the path to the style image.
style_reference_image_path =  'romanticism.jpg'

width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %%
import numpy as np
from keras.applications import vgg19

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
print('Model loaded.')
# Out:
# Model loaded.

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram


def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :])
    b = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-3
style_weight = 0.5
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result'
iterations = 50

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 337340640.0
# Image saved as style_transfer_result_at_iteration_0.png
# Iteration 0 completed in 14s
# Start of iteration 1
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:24: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Current loss value: 161718220.0
# Image saved as style_transfer_result_at_iteration_1.png
# Iteration 1 completed in 9s
# Start of iteration 2
# Current loss value: 107638730.0
# Image saved as style_transfer_result_at_iteration_2.png
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 85179220.0
# Image saved as style_transfer_result_at_iteration_3.png
# Iteration 3 completed in 9s
# Start of iteration 4
# Current loss value: 72259230.0
# Image saved as style_transfer_result_at_iteration_4.png
# Iteration 4 completed in 9s
# Start of iteration 5
# Current loss value: 64233250.0
# Image saved as style_transfer_result_at_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6
# Current loss value: 58666936.0
# Image saved as style_transfer_result_at_iteration_6.png
# Iteration 6 completed in 9s
# Start of iteration 7
# Current loss value: 54172716.0
# Image saved as style_transfer_result_at_iteration_7.png
# Iteration 7 completed in 9s
# Start of iteration 8
# Current loss value: 49970336.0
# Image saved as style_transfer_result_at_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9
# Current loss value: 46788190.0
# Image saved as style_transfer_result_at_iteration_9.png
# Iteration 9 completed in 9s
# Start of iteration 10
# Current loss value: 44349460.0
# Image saved as style_transfer_result_at_iteration_10.png
# Iteration 10 completed in 9s
# Start of iteration 11
# Current loss value: 41669910.0
# Image saved as style_transfer_result_at_iteration_11.png
# Iteration 11 completed in 9s
# Start of iteration 12
# Current loss value: 39507820.0
# Image saved as style_transfer_result_at_iteration_12.png
# Iteration 12 completed in 9s
# Start of iteration 13
# Current loss value: 37735240.0
# Image saved as style_transfer_result_at_iteration_13.png
# Iteration 13 completed in 9s
# Start of iteration 14
# Current loss value: 36240670.0
# Image saved as style_transfer_result_at_iteration_14.png
# Iteration 14 completed in 9s
# Start of iteration 15
# Current loss value: 34910604.0
# Image saved as style_transfer_result_at_iteration_15.png
# Iteration 15 completed in 9s
# Start of iteration 16
# Current loss value: 33544744.0
# Image saved as style_transfer_result_at_iteration_16.png
# Iteration 16 completed in 9s
# Start of iteration 17
# Current loss value: 32419340.0
# Image saved as style_transfer_result_at_iteration_17.png
# Iteration 17 completed in 9s
# Start of iteration 18
# Current loss value: 31391604.0
# Image saved as style_transfer_result_at_iteration_18.png
# Iteration 18 completed in 9s
# Start of iteration 19
# Current loss value: 30455630.0
# Image saved as style_transfer_result_at_iteration_19.png
# Iteration 19 completed in 9s
# Start of iteration 20
# Current loss value: 29480032.0
# Image saved as style_transfer_result_at_iteration_20.png
# Iteration 20 completed in 9s
# Start of iteration 21
# Current loss value: 28664702.0
# Image saved as style_transfer_result_at_iteration_21.png
# Iteration 21 completed in 9s
# Start of iteration 22
# Current loss value: 27941510.0
# Image saved as style_transfer_result_at_iteration_22.png
# Iteration 22 completed in 9s
# Start of iteration 23
# Current loss value: 27112424.0
# Image saved as style_transfer_result_at_iteration_23.png
# Iteration 23 completed in 9s
# Start of iteration 24
# Current loss value: 26446660.0
# Image saved as style_transfer_result_at_iteration_24.png
# Iteration 24 completed in 9s
# Start of iteration 25
# Current loss value: 25871686.0
# Image saved as style_transfer_result_at_iteration_25.png
# Iteration 25 completed in 9s
# Start of iteration 26
# Current loss value: 25214908.0
# Image saved as style_transfer_result_at_iteration_26.png
# Iteration 26 completed in 9s
# Start of iteration 27
# Current loss value: 24577492.0
# Image saved as style_transfer_result_at_iteration_27.png
# Iteration 27 completed in 9s
# Start of iteration 28
# Current loss value: 24030344.0
# Image saved as style_transfer_result_at_iteration_28.png
# Iteration 28 completed in 10s
# Start of iteration 29
# Current loss value: 23532054.0
# Image saved as style_transfer_result_at_iteration_29.png
# Iteration 29 completed in 9s
# Start of iteration 30
# Current loss value: 23065664.0
# Image saved as style_transfer_result_at_iteration_30.png
# Iteration 30 completed in 9s
# Start of iteration 31
# Current loss value: 22631802.0
# Image saved as style_transfer_result_at_iteration_31.png
# Iteration 31 completed in 9s
# Start of iteration 32
# Current loss value: 22213640.0
# Image saved as style_transfer_result_at_iteration_32.png
# Iteration 32 completed in 9s
# Start of iteration 33
# Current loss value: 21799458.0
# Image saved as style_transfer_result_at_iteration_33.png
# Iteration 33 completed in 9s
# Start of iteration 34
# Current loss value: 21433630.0
# Image saved as style_transfer_result_at_iteration_34.png
# Iteration 34 completed in 9s
# Start of iteration 35
# Current loss value: 21093974.0
# Image saved as style_transfer_result_at_iteration_35.png
# Iteration 35 completed in 9s
# Start of iteration 36
# Current loss value: 20562642.0
# Image saved as style_transfer_result_at_iteration_36.png
# Iteration 36 completed in 9s
# Start of iteration 37
# Current loss value: 20077862.0
# Image saved as style_transfer_result_at_iteration_37.png
# Iteration 37 completed in 9s
# Start of iteration 38
# Current loss value: 19665318.0
# Image saved as style_transfer_result_at_iteration_38.png
# Iteration 38 completed in 9s
# Start of iteration 39
# Current loss value: 19334294.0
# Image saved as style_transfer_result_at_iteration_39.png
# Iteration 39 completed in 9s
# Start of iteration 40
# Current loss value: 19046406.0
# Image saved as style_transfer_result_at_iteration_40.png
# Iteration 40 completed in 9s
# Start of iteration 41
# Current loss value: 18775678.0
# Image saved as style_transfer_result_at_iteration_41.png
# Iteration 41 completed in 9s
# Start of iteration 42
# Current loss value: 18539098.0
# Image saved as style_transfer_result_at_iteration_42.png
# Iteration 42 completed in 9s
# Start of iteration 43
# Current loss value: 18305638.0
# Image saved as style_transfer_result_at_iteration_43.png
# Iteration 43 completed in 9s
# Start of iteration 44
# Current loss value: 18088568.0
# Image saved as style_transfer_result_at_iteration_44.png
# Iteration 44 completed in 9s
# Start of iteration 45
# Current loss value: 17863818.0
# Image saved as style_transfer_result_at_iteration_45.png
# Iteration 45 completed in 9s
# Start of iteration 46
# Current loss value: 17648284.0
# Image saved as style_transfer_result_at_iteration_46.png
# Iteration 46 completed in 9s
# Start of iteration 47
# Current loss value: 17367174.0
# Image saved as style_transfer_result_at_iteration_47.png
# Iteration 47 completed in 9s
# Start of iteration 48
# Current loss value: 17075786.0
# Image saved as style_transfer_result_at_iteration_48.png
# Iteration 48 completed in 9s
# Start of iteration 49
# Current loss value: 16859316.0
# Image saved as style_transfer_result_at_iteration_49.png
# Iteration 49 completed in 9s

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()

# %%
imsave('transition.jpg', img)

# This is the path to the image you want to transform.
target_image_path = 'transition.jpg'
# This is the path to the style image.
style_reference_image_path =  'Picasso.jpg'

width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   if __name__ == '__main__':

# %%
# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# %%
target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
print('Model loaded.')
# Out:
# Model loaded.

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-3
style_weight = 0.5
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])

evaluator = Evaluator()

# %%
result_prefix = 'style_transfer_result_p2'
iterations = 50

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1253120100.0
# Image saved as style_transfer_result_p2_at_iteration_0.png
# Iteration 0 completed in 10s
# Start of iteration 1
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:20: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Current loss value: 564066050.0
# Image saved as style_transfer_result_p2_at_iteration_1.png
# Iteration 1 completed in 9s
# Start of iteration 2
# Current loss value: 344643600.0
# Image saved as style_transfer_result_p2_at_iteration_2.png
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 255822880.0
# Image saved as style_transfer_result_p2_at_iteration_3.png
# Iteration 3 completed in 9s
# Start of iteration 4
# Current loss value: 205788830.0
# Image saved as style_transfer_result_p2_at_iteration_4.png
# Iteration 4 completed in 9s
# Start of iteration 5
# Current loss value: 178540260.0
# Image saved as style_transfer_result_p2_at_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6
# Current loss value: 160292080.0
# Image saved as style_transfer_result_p2_at_iteration_6.png
# Iteration 6 completed in 9s
# Start of iteration 7
# Current loss value: 144691780.0
# Image saved as style_transfer_result_p2_at_iteration_7.png
# Iteration 7 completed in 9s
# Start of iteration 8
# Current loss value: 135005100.0
# Image saved as style_transfer_result_p2_at_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9
# Current loss value: 126797840.0
# Image saved as style_transfer_result_p2_at_iteration_9.png
# Iteration 9 completed in 9s
# Start of iteration 10
# Current loss value: 117261890.0
# Image saved as style_transfer_result_p2_at_iteration_10.png
# Iteration 10 completed in 9s
# Start of iteration 11
# Current loss value: 110481320.0
# Image saved as style_transfer_result_p2_at_iteration_11.png
# Iteration 11 completed in 9s
# Start of iteration 12
# Current loss value: 104574980.0
# Image saved as style_transfer_result_p2_at_iteration_12.png
# Iteration 12 completed in 9s
# Start of iteration 13
# Current loss value: 99943896.0
# Image saved as style_transfer_result_p2_at_iteration_13.png
# Iteration 13 completed in 9s
# Start of iteration 14
# Current loss value: 96250280.0
# Image saved as style_transfer_result_p2_at_iteration_14.png
# Iteration 14 completed in 9s
# Start of iteration 15
# Current loss value: 92018696.0
# Image saved as style_transfer_result_p2_at_iteration_15.png
# Iteration 15 completed in 9s
# Start of iteration 16
# Current loss value: 88825580.0
# Image saved as style_transfer_result_p2_at_iteration_16.png
# Iteration 16 completed in 9s
# Start of iteration 17
# Current loss value: 86211480.0
# Image saved as style_transfer_result_p2_at_iteration_17.png
# Iteration 17 completed in 9s
# Start of iteration 18
# Current loss value: 83947544.0
# Image saved as style_transfer_result_p2_at_iteration_18.png
# Iteration 18 completed in 9s
# Start of iteration 19
# Current loss value: 81885060.0
# Image saved as style_transfer_result_p2_at_iteration_19.png
# Iteration 19 completed in 9s
# Start of iteration 20
# Current loss value: 79681576.0
# Image saved as style_transfer_result_p2_at_iteration_20.png
# Iteration 20 completed in 9s
# Start of iteration 21
# Current loss value: 77660400.0
# Image saved as style_transfer_result_p2_at_iteration_21.png
# Iteration 21 completed in 10s
# Start of iteration 22
# Current loss value: 75974740.0
# Image saved as style_transfer_result_p2_at_iteration_22.png
# Iteration 22 completed in 9s
# Start of iteration 23
# Current loss value: 74375016.0
# Image saved as style_transfer_result_p2_at_iteration_23.png
# Iteration 23 completed in 9s
# Start of iteration 24
# Current loss value: 73078340.0
# Image saved as style_transfer_result_p2_at_iteration_24.png
# Iteration 24 completed in 9s
# Start of iteration 25

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()

# %%
# This is the path to the image you want to transform.
target_image_path = 'xl_earring.jpg'
# This is the path to the style image.
style_reference_image_path =  'Picasso.jpg'

width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)

# %%
target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
print('Model loaded.')
# Out:
# Model loaded.

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-3
style_weight = 0.5
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])

evaluator = Evaluator()

# %%
result_prefix = 'style_transfer_result_p2'
iterations = 50

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1034138200.0
# Image saved as style_transfer_result_p2_at_iteration_0.png
# Iteration 0 completed in 10s
# Start of iteration 1
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:20: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Current loss value: 517769570.0
# Image saved as style_transfer_result_p2_at_iteration_1.png
# Iteration 1 completed in 9s
# Start of iteration 2
# Current loss value: 351220670.0
# Image saved as style_transfer_result_p2_at_iteration_2.png
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 265845230.0
# Image saved as style_transfer_result_p2_at_iteration_3.png
# Iteration 3 completed in 9s
# Start of iteration 4
# Current loss value: 225100200.0
# Image saved as style_transfer_result_p2_at_iteration_4.png
# Iteration 4 completed in 9s
# Start of iteration 5
# Current loss value: 195312450.0
# Image saved as style_transfer_result_p2_at_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6
# Current loss value: 176206560.0
# Image saved as style_transfer_result_p2_at_iteration_6.png
# Iteration 6 completed in 9s
# Start of iteration 7
# Current loss value: 163195620.0
# Image saved as style_transfer_result_p2_at_iteration_7.png
# Iteration 7 completed in 9s
# Start of iteration 8
# Current loss value: 152323540.0
# Image saved as style_transfer_result_p2_at_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9
# Current loss value: 143587920.0
# Image saved as style_transfer_result_p2_at_iteration_9.png
# Iteration 9 completed in 9s
# Start of iteration 10
# Current loss value: 136781020.0
# Image saved as style_transfer_result_p2_at_iteration_10.png
# Iteration 10 completed in 9s
# Start of iteration 11
# Current loss value: 128432750.0
# Image saved as style_transfer_result_p2_at_iteration_11.png
# Iteration 11 completed in 9s
# Start of iteration 12
# Current loss value: 122887520.0
# Image saved as style_transfer_result_p2_at_iteration_12.png
# Iteration 12 completed in 9s
# Start of iteration 13
# Current loss value: 117219130.0
# Image saved as style_transfer_result_p2_at_iteration_13.png
# Iteration 13 completed in 9s
# Start of iteration 14
# Current loss value: 112652776.0
# Image saved as style_transfer_result_p2_at_iteration_14.png
# Iteration 14 completed in 9s
# Start of iteration 15
# Current loss value: 108239570.0
# Image saved as style_transfer_result_p2_at_iteration_15.png
# Iteration 15 completed in 9s
# Start of iteration 16
# Current loss value: 104389020.0
# Image saved as style_transfer_result_p2_at_iteration_16.png
# Iteration 16 completed in 9s
# Start of iteration 17
# Current loss value: 101315730.0
# Image saved as style_transfer_result_p2_at_iteration_17.png
# Iteration 17 completed in 9s
# Start of iteration 18
# Current loss value: 98745170.0
# Image saved as style_transfer_result_p2_at_iteration_18.png
# Iteration 18 completed in 9s
# Start of iteration 19
# Current loss value: 96351770.0
# Image saved as style_transfer_result_p2_at_iteration_19.png
# Iteration 19 completed in 9s
# Start of iteration 20
# Current loss value: 93816344.0
# Image saved as style_transfer_result_p2_at_iteration_20.png
# Iteration 20 completed in 9s
# Start of iteration 21
# Current loss value: 91546230.0
# Image saved as style_transfer_result_p2_at_iteration_21.png
# Iteration 21 completed in 9s
# Start of iteration 22
# Current loss value: 89629944.0
# Image saved as style_transfer_result_p2_at_iteration_22.png
# Iteration 22 completed in 9s
# Start of iteration 23
# Current loss value: 87797340.0
# Image saved as style_transfer_result_p2_at_iteration_23.png
# Iteration 23 completed in 9s
# Start of iteration 24
# Current loss value: 85793950.0
# Image saved as style_transfer_result_p2_at_iteration_24.png
# Iteration 24 completed in 9s
# Start of iteration 25
# Current loss value: 84098250.0
# Image saved as style_transfer_result_p2_at_iteration_25.png
# Iteration 25 completed in 9s
# Start of iteration 26
# Current loss value: 82335170.0
# Image saved as style_transfer_result_p2_at_iteration_26.png
# Iteration 26 completed in 9s
# Start of iteration 27
# Current loss value: 80619944.0
# Image saved as style_transfer_result_p2_at_iteration_27.png
# Iteration 27 completed in 9s
# Start of iteration 28
# Current loss value: 79215096.0
# Image saved as style_transfer_result_p2_at_iteration_28.png
# Iteration 28 completed in 9s
# Start of iteration 29
# Current loss value: 77963560.0
# Image saved as style_transfer_result_p2_at_iteration_29.png
# Iteration 29 completed in 9s
# Start of iteration 30
# Current loss value: 76822990.0
# Image saved as style_transfer_result_p2_at_iteration_30.png
# Iteration 30 completed in 9s
# Start of iteration 31
# Current loss value: 75458200.0
# Image saved as style_transfer_result_p2_at_iteration_31.png
# Iteration 31 completed in 9s
# Start of iteration 32
# Current loss value: 74323610.0
# Image saved as style_transfer_result_p2_at_iteration_32.png
# Iteration 32 completed in 9s
# Start of iteration 33
# Current loss value: 73207976.0
# Image saved as style_transfer_result_p2_at_iteration_33.png
# Iteration 33 completed in 9s
# Start of iteration 34
# Current loss value: 72250984.0
# Image saved as style_transfer_result_p2_at_iteration_34.png
# Iteration 34 completed in 9s
# Start of iteration 35
# Current loss value: 71276504.0
# Image saved as style_transfer_result_p2_at_iteration_35.png
# Iteration 35 completed in 9s
# Start of iteration 36
# Current loss value: 70402300.0
# Image saved as style_transfer_result_p2_at_iteration_36.png
# Iteration 36 completed in 9s
# Start of iteration 37
# Current loss value: 69366776.0
# Image saved as style_transfer_result_p2_at_iteration_37.png
# Iteration 37 completed in 9s
# Start of iteration 38
# Current loss value: 68327300.0
# Image saved as style_transfer_result_p2_at_iteration_38.png
# Iteration 38 completed in 9s
# Start of iteration 39
# Current loss value: 67114590.0
# Image saved as style_transfer_result_p2_at_iteration_39.png
# Iteration 39 completed in 9s
# Start of iteration 40
# Current loss value: 65950836.0
# Image saved as style_transfer_result_p2_at_iteration_40.png
# Iteration 40 completed in 9s
# Start of iteration 41
# Current loss value: 65096620.0
# Image saved as style_transfer_result_p2_at_iteration_41.png
# Iteration 41 completed in 9s
# Start of iteration 42
# Current loss value: 64264600.0
# Image saved as style_transfer_result_p2_at_iteration_42.png
# Iteration 42 completed in 9s
# Start of iteration 43
# Current loss value: 63427948.0
# Image saved as style_transfer_result_p2_at_iteration_43.png
# Iteration 43 completed in 9s
# Start of iteration 44
# Current loss value: 62665850.0
# Image saved as style_transfer_result_p2_at_iteration_44.png
# Iteration 44 completed in 9s
# Start of iteration 45
# Current loss value: 61947296.0
# Image saved as style_transfer_result_p2_at_iteration_45.png
# Iteration 45 completed in 9s
# Start of iteration 46
# Current loss value: 61213750.0
# Image saved as style_transfer_result_p2_at_iteration_46.png
# Iteration 46 completed in 9s
# Start of iteration 47
# Current loss value: 60443196.0
# Image saved as style_transfer_result_p2_at_iteration_47.png
# Iteration 47 completed in 9s
# Start of iteration 48
# Current loss value: 59699292.0
# Image saved as style_transfer_result_p2_at_iteration_48.png
# Iteration 48 completed in 9s
# Start of iteration 49
# Current loss value: 59130852.0
# Image saved as style_transfer_result_p2_at_iteration_49.png
# Iteration 49 completed in 9s

# %%
# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()
